# %%
import pandas as pd

pd.set_option('display.max_rows', None)

ds = pd.read_csv("./output.csv")
ds.head(200)
# Out:
#      event  obj  typ         eta       phi          pt     jmass  ntrk  btag  \
# 0        0    0    1  999.900000  0.000000    0.000000  0.000511  -1.0   0.0
# 1        0    1    1  999.900000  0.000000    0.000000  0.000000  -1.0   0.0
# 2        0    2    1 -999.900000  0.000000    0.000000  0.000511   1.0   0.0
# 3        0    3    1 -999.900000  0.000000    0.000000  0.000000   1.0   0.0
# 4        0    4    2   -0.802559 -2.895381   19.979410  0.105660  -1.0   0.0
# 5        0    5    2    0.878578  2.420645   97.765320  0.105660   1.0   0.0
# 6        0    6    2    0.878802  2.420792   97.732840  0.105660   1.0   0.0
# 7        0    7    0   -0.243636  2.322414    0.039873  0.000000   0.0   0.0
# 8        0    8    2   -0.802559 -2.895381   19.966726  0.105660  -1.0   0.0
# 9        0    9    2    0.878802  2.420792   97.732830  0.105660   1.0   0.0
# 10       0   10    0    0.533977  2.364734    0.000020  0.000000   0.0   0.0
# ...
